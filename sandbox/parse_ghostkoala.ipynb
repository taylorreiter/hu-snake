# %%
import pandas as pd

# %%
input = '../outputs/hu-crumbs_gold/assembly/GhostKOALA/user_ko_definition.txt'

# %%
hu = pd.read_table(input, header=None)

# %%
hu[0] = hu[0].replace("user:",  "", regex = True)

# %%
hu.head
# Out:
# <bound method NDFrame.head of                                0       1  \
# 0      hu-genome02_goldass_00001     NaN
# 1      hu-genome02_goldass_00002     NaN
# 2      hu-genome02_goldass_00003     NaN
# 3      hu-genome02_goldass_00004     NaN
# 4      hu-genome02_goldass_00005  K04798
# 5      hu-genome02_goldass_00006  K07333
# 6      hu-genome02_goldass_00007  K15635
# 7      hu-genome02_goldass_00008     NaN
# 8      hu-genome02_goldass_00009  K03408
# 9      hu-genome02_goldass_00010     NaN
# 10     hu-genome02_goldass_00011     NaN
# 11     hu-genome02_goldass_00012     NaN
# 12     hu-genome02_goldass_00013     NaN
# 13     hu-genome02_goldass_00014     NaN
# 14     hu-genome02_goldass_00016  K16011
# 15     hu-genome02_goldass_00017     NaN
# 16     hu-genome02_goldass_00018     NaN
# 17     hu-genome02_goldass_00019     NaN
# 18     hu-genome02_goldass_00020     NaN
# 19     hu-genome02_goldass_00021  K07583
# 20     hu-genome02_goldass_00022     NaN
# ...

# %%
hu[6] = hu[0].replace("_goldass_[0-9]{5,6}", "", regex = True)
#hu[6] = hu[6].replace("_goldmhsub_[0-9]{5,6}", "", regex = True)

# %%
for sample, hu_bin in hu.groupby(6):
    print(sample)
    #hu_bin.to_csv(f"outputs/gold_prots/{sample}.txt", index = False, header = False, sep = "\t")
# Out:
# hu-genome02
# hu-genome03
# hu-genome08
# hu-genome10
# hu-genome11
# hu-genome12
# hu-genome13
# hu-genome14
# hu-genome19
# hu-genome20
# hu-genome21
# hu-genome22
# hu-genome23
# hu-genome24
# hu-genome25
# hu-genome26
# hu-genome27
# hu-genome28
# hu-genome29
# hu-genome30
# hu-genome31
# hu-genome33
# hu-genome34
# hu-genome35
# hu-genome36
# hu-genome37
# hu-genome38
# hu-genome39
# hu-genome40
# hu-genome41

# %%
input = '../outputs/hu-crumbs_gold/assembly/GhostKOALA/user.out.top'

# %%
tax = pd.read_table(input, header=None)
tax[0] = tax[0].replace("user:",  "", regex = True)
tax[7] = tax[0].replace("_goldass_[0-9]{5,6}", "", regex = True)

# %%
tax.head
# Out:
# <bound method NDFrame.head of                                0       1         2  \
# 0      hu-genome02_goldass_00001     NaN   Animals
# 1      hu-genome02_goldass_00002     NaN  Bacteria
# 2      hu-genome02_goldass_00003  K03686   Archaea
# 3      hu-genome02_goldass_00004  K00981  Bacteria
# 4      hu-genome02_goldass_00005  K04798   Archaea
# 5      hu-genome02_goldass_00006  K07333   Archaea
# 6      hu-genome02_goldass_00007  K15635   Archaea
# 7      hu-genome02_goldass_00008     NaN   Archaea
# 8      hu-genome02_goldass_00009  K03408   Archaea
# 9      hu-genome02_goldass_00010     NaN   Archaea
# 10     hu-genome02_goldass_00011     NaN   Archaea
# 11     hu-genome02_goldass_00012     NaN  Bacteria
# 12     hu-genome02_goldass_00013     NaN   Archaea
# 13     hu-genome02_goldass_00014     NaN  Protists
# 14     hu-genome02_goldass_00016  K16011   Archaea
# 15     hu-genome02_goldass_00017     NaN     Fungi
# 16     hu-genome02_goldass_00018     NaN  Bacteria
# ...

# %%
hu[7] = hu[0].replace("_[0-9]{5,6}", "", regex = True)

# %%
for sample, hu_bin in tax.groupby(7):
    print(sample)
    #hu_bin.to_csv(f"outputs/gold_prots/{sample}.txt", index = False, header = False, sep = "\t")
# Out:
# hu-genome02
# hu-genome03
# hu-genome08
# hu-genome10
# hu-genome11
# hu-genome12
# hu-genome13
# hu-genome14
# hu-genome19
# hu-genome20
# hu-genome21
# hu-genome22
# hu-genome23
# hu-genome24
# hu-genome25
# hu-genome26
# hu-genome27
# hu-genome28
# hu-genome29
# hu-genome30
# hu-genome31
# hu-genome33
# hu-genome34
# hu-genome35
# hu-genome36
# hu-genome37
# hu-genome38
# hu-genome39
# hu-genome40
# hu-genome41
